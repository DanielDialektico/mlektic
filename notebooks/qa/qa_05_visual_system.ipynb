# %% [markdown]
# # QA 05 — themes, formats, density, and sizes
#
# Every supported visual-system preset plus overrides and responsive metadata.

# %% [markdown]
# > Run this notebook from top to bottom after installing the project with
# > `pip install -e ".[notebooks]"`. Figures are genuine public-API outputs.
# > Cells intentionally contain no assertions: automated invariants live in
# > `tests/`, while this notebook is for human visual inspection.

# %%
from pathlib import Path
import sys

candidate = Path.cwd().resolve()
while candidate != candidate.parent and not (candidate / "pyproject.toml").exists():
    candidate = candidate.parent
if not (candidate / "pyproject.toml").exists():
    raise RuntimeError("Open this notebook from inside the Mlektic repository.")
ROOT = candidate
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from IPython.display import display
from mlektic import visualize_lr
from notebooks._support import case_heading, linear_case
c=linear_case(1)

# %% [markdown]
# ### `STYLE-THEME-CLASSIC`
#
# **Inspect:** classic visual tokens without changing model semantics

# %%
case_heading("STYLE-THEME-CLASSIC", "classic visual tokens without changing model semantics")
display(visualize_lr(c.model,c.X,c.y,steps=7,max_frames=5,theme='classic'))

# %% [markdown]
# ### `STYLE-THEME-ACADEMIC`
#
# **Inspect:** academic visual tokens without changing model semantics

# %%
case_heading("STYLE-THEME-ACADEMIC", "academic visual tokens without changing model semantics")
display(visualize_lr(c.model,c.X,c.y,steps=7,max_frames=5,theme='academic'))

# %% [markdown]
# ### `STYLE-THEME-CLASSROOM`
#
# **Inspect:** classroom visual tokens without changing model semantics

# %%
case_heading("STYLE-THEME-CLASSROOM", "classroom visual tokens without changing model semantics")
display(visualize_lr(c.model,c.X,c.y,steps=7,max_frames=5,theme='classroom'))

# %% [markdown]
# ### `STYLE-THEME-COMPACT`
#
# **Inspect:** compact visual tokens without changing model semantics

# %%
case_heading("STYLE-THEME-COMPACT", "compact visual tokens without changing model semantics")
display(visualize_lr(c.model,c.X,c.y,steps=7,max_frames=5,theme='compact'))

# %% [markdown]
# ### `STYLE-THEME-ACCESSIBLE`
#
# **Inspect:** accessible visual tokens without changing model semantics

# %%
case_heading("STYLE-THEME-ACCESSIBLE", "accessible visual tokens without changing model semantics")
display(visualize_lr(c.model,c.X,c.y,steps=7,max_frames=5,theme='accessible'))

# %% [markdown]
# ### `STYLE-FORMAT-DASHBOARD`
#
# **Inspect:** dashboard composition and its documented motion behavior

# %%
case_heading("STYLE-FORMAT-DASHBOARD", "dashboard composition and its documented motion behavior")
display(visualize_lr(c.model,c.X,c.y,steps=7,max_frames=5,format='dashboard',theme='academic'))

# %% [markdown]
# ### `STYLE-FORMAT-LESSON`
#
# **Inspect:** lesson composition and its documented motion behavior

# %%
case_heading("STYLE-FORMAT-LESSON", "lesson composition and its documented motion behavior")
display(visualize_lr(c.model,c.X,c.y,steps=7,max_frames=5,format='lesson',theme='academic'))

# %% [markdown]
# ### `STYLE-FORMAT-COMPACT`
#
# **Inspect:** compact composition and its documented motion behavior

# %%
case_heading("STYLE-FORMAT-COMPACT", "compact composition and its documented motion behavior")
display(visualize_lr(c.model,c.X,c.y,steps=7,max_frames=5,format='compact',theme='academic'))

# %% [markdown]
# ### `STYLE-FORMAT-REPORT`
#
# **Inspect:** report composition and its documented motion behavior

# %%
case_heading("STYLE-FORMAT-REPORT", "report composition and its documented motion behavior")
display(visualize_lr(c.model,c.X,c.y,steps=7,max_frames=5,format='report',theme='academic'))

# %% [markdown]
# ### `STYLE-SIZE-DEFAULT`
#
# **Inspect:** default canvas preset and readable labels

# %%
case_heading("STYLE-SIZE-DEFAULT", "default canvas preset and readable labels")
display(visualize_lr(c.model,c.X,c.y,steps=7,max_frames=5,size='default',theme='academic'))

# %% [markdown]
# ### `STYLE-SIZE-COMPACT`
#
# **Inspect:** compact canvas preset and readable labels

# %%
case_heading("STYLE-SIZE-COMPACT", "compact canvas preset and readable labels")
display(visualize_lr(c.model,c.X,c.y,steps=7,max_frames=5,size='compact',theme='academic'))

# %% [markdown]
# ### `STYLE-SIZE-NOTEBOOK`
#
# **Inspect:** notebook canvas preset and readable labels

# %%
case_heading("STYLE-SIZE-NOTEBOOK", "notebook canvas preset and readable labels")
display(visualize_lr(c.model,c.X,c.y,steps=7,max_frames=5,size='notebook',theme='academic'))

# %% [markdown]
# ### `STYLE-SIZE-WIDE`
#
# **Inspect:** wide canvas preset and readable labels

# %%
case_heading("STYLE-SIZE-WIDE", "wide canvas preset and readable labels")
display(visualize_lr(c.model,c.X,c.y,steps=7,max_frames=5,size='wide',theme='academic'))

# %% [markdown]
# ### `STYLE-SIZE-CLASSROOM`
#
# **Inspect:** classroom canvas preset and readable labels

# %%
case_heading("STYLE-SIZE-CLASSROOM", "classroom canvas preset and readable labels")
display(visualize_lr(c.model,c.X,c.y,steps=7,max_frames=5,size='classroom',theme='academic'))

# %% [markdown]
# ### `STYLE-RESPONSIVE`
#
# **Inspect:** responsive config metadata and container scaling

# %%
case_heading("STYLE-RESPONSIVE", "responsive config metadata and container scaling")
display(visualize_lr(c.model,c.X,c.y,steps=7,max_frames=5,responsive=True,size='notebook'))

# %% [markdown]
# ### `STYLE-EXPLICIT-SIZE`
#
# **Inspect:** explicit width and height overriding the preset

# %%
case_heading("STYLE-EXPLICIT-SIZE", "explicit width and height overriding the preset")
display(visualize_lr(c.model,c.X,c.y,steps=7,max_frames=5,width=960,height=640))

# %% [markdown]
# ### `STYLE-DENSITY-ESSENTIAL`
#
# **Inspect:** compact essential mathematics

# %%
case_heading("STYLE-DENSITY-ESSENTIAL", "compact essential mathematics")
display(visualize_lr(c.model,c.X,c.y,steps=7,max_frames=5,density='essential'))

# %% [markdown]
# ### `STYLE-DENSITY-ACADEMIC`
#
# **Inspect:** fitted-model derivation below the animation

# %%
case_heading("STYLE-DENSITY-ACADEMIC", "fitted-model derivation below the animation")
display(visualize_lr(c.model,c.X,c.y,steps=7,max_frames=5,density='academic',size='wide'))

# %% [markdown]
# ### `STYLE-DENSITY-COMPLETE`
#
# **Inspect:** objective, preprocessing, and caveat panels

# %%
case_heading("STYLE-DENSITY-COMPLETE", "objective, preprocessing, and caveat panels")
display(visualize_lr(c.model,c.X,c.y,steps=7,max_frames=5,density='complete',size='wide'))

# %% [markdown]
# ### `STYLE-HISTORY-HIDDEN`
#
# **Inspect:** history subtitle hidden while slider and metadata retain provenance

# %%
case_heading("STYLE-HISTORY-HIDDEN", "history subtitle hidden while slider and metadata retain provenance")
display(visualize_lr(c.model,c.X,c.y,steps=7,max_frames=5,show_history_context=False))
